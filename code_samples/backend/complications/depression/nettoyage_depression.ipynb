# %%
# Lit le fichier CSV  et le charge dans un DataFrame 'df'
import pandas as pd
# df= pd.read_csv("../../Datasets/Datasets Maladies/data_collected_finale.csv")
df= pd.read_csv("../../datasets/datasets_complications/dataset_depression.csv")
df
# Out:
#        Unnamed: 0                                            content
# 0               0  RT @DoreenCaven: I fear that people watch so m...
# 1               1  RT @KaroroMitchelle: Not about to spend the re...
# 2               2  RT @awanz05: Urgent Appeal for Action\n#Arrest...
# 3               5  RT @ShivanyaSitole: #GodMorningFriday \n#सर्वश...
# 4               6  RT @patriciaflima12: “Trust me, I'm not leavin...
# ...           ...                                                ...
# 12301       18573                                         catasters:
# 12302       18574  zegalba:Mount Fuji seen from the International...
# 12303       18575  thehopefulquotes:\n“Loving someone means takin...
# 12304       18576  perfectfeelings:\n“I want to talk about what h...
# 12305       18577  perfeqt:\n“Always end the day with a positive ...
#
# [12306 rows x 2 columns]

# %%
# Afficher les lignes dupliquées
duplicated_rows = df.duplicated()

print("\nLignes dupliquées (chaque valeur ""True"" indique une ligne dupliquée.")
print(duplicated_rows)

# Compter le nombre de lignes dupliquées
num_duplicated_rows = duplicated_rows.sum()
print(f"\nNombre de lignes dupliquées: {num_duplicated_rows}")
# Out:
# Lignes dupliquées (chaque valeur True indique une ligne dupliquée.
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12301    False
# 12302    False
# 12303    False
# 12304    False
# 12305    False
# Length: 12306, dtype: bool
#
# Nombre de lignes dupliquées: 0

# %%
# Supprimer les lignes dupliquées
df_without_duplicates = df.drop_duplicates()

# Afficher la DataFrame sans duplications pour référence
print("\nDataFrame sans duplications:")
print(df_without_duplicates)

# Réassigner la DataFrame originale pour contenir uniquement les lignes uniques
df = df_without_duplicates

# Afficher la DataFrame mise à jour
print("\nDataFrame mise à jour sans duplications:")
print(df)
df.to_csv('data_finale.csv')
# Out:
# DataFrame sans duplications:
#        Unnamed: 0                                            content
# 0               0  RT @DoreenCaven: I fear that people watch so m...
# 1               1  RT @KaroroMitchelle: Not about to spend the re...
# 2               2  RT @awanz05: Urgent Appeal for Action\n#Arrest...
# 3               5  RT @ShivanyaSitole: #GodMorningFriday \n#सर्वश...
# 4               6  RT @patriciaflima12: “Trust me, I'm not leavin...
# ...           ...                                                ...
# 12301       18573                                         catasters:
# 12302       18574  zegalba:Mount Fuji seen from the International...
# 12303       18575  thehopefulquotes:\n“Loving someone means takin...
# 12304       18576  perfectfeelings:\n“I want to talk about what h...
# 12305       18577  perfeqt:\n“Always end the day with a positive ...
#
# [12306 rows x 2 columns]
#
# DataFrame mise à jour sans duplications:
# ...

# %%
# # Vérifier les lignes manquantes
# print(df.isnull().sum())  # Montre combien de NaN dans chaque colonne

# # Supprimer les lignes avec du texte manquant
# df = df.dropna(subset=['content'])
# Out:
# Unnamed: 0    0
# content       0
# dtype: int64

# %%
import re
def clean_text(text):
    if isinstance(text, str):

        text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
        text = re.sub(r'#\S+', '', text, flags=re.MULTILINE) 

    return text
df['content']=df['content'].apply(clean_text)
df.head()
# Out:
#    Unnamed: 0                                            content
# 0           0  RT @DoreenCaven: I fear that people watch so m...
# 1           1  RT @KaroroMitchelle: Not about to spend the re...
# 2           2  RT @awanz05: Urgent Appeal for Action\n\n\nI c...
# 3           5  RT @ShivanyaSitole:  \n\n\nSupreme God Kabir\n...
# 4           6  RT @patriciaflima12: “Trust me, I'm not leavin...

# %%
#Remplacer les contractions dans le texte par leur forme complète
# clé:valeur
contractions_dict = { "ain't": "are not","'s":" is","aren't": "are not",
                     "can't": "cannot","can't've": "cannot have",
                     "'cause": "because","could've": "could have","couldn't": "could not",
                     "couldn't've": "could not have", "didn't": "did not","doesn't": "does not",
                     "don't": "do not","hadn't": "had not","hadn't've": "had not have",
                     "hasn't": "has not","haven't": "have not","he'd": "he would",
                     "he'd've": "he would have","he'll": "he will", "he'll've": "he will have",
                     "how'd": "how did","how'd'y": "how do you","how'll": "how will",
                     "i'd": "i would", "i'd've": "i would have","i'll": "i will",
                     "i'll've": "i will have","i'm": "i am","I've": "i have", "isn't": "is not",
                     "it'd": "it would","it'd've": "it would have","it'll": "it will",
                     "it'll've": "it will have", "let's": "let us","ma'am": "madam",
                     "mayn't": "may not","might've": "might have","mightn't": "might not",
                     "mightn't've": "might not have","must've": "must have","mustn't": "must not",
                     "mustn't've": "must not have", "needn't": "need not",
                     "needn't've": "need not have","o'clock": "of the clock","oughtn't": "ought not",
                     "oughtn't've": "ought not have","shan't": "shall not","sha'n't": "shall not",
                     "shan't've": "shall not have","she'd": "she would","she'd've": "she would have",
                     "she'll": "she will", "she'll've": "she will have","should've": "should have",
                     "shouldn't": "should not", "shouldn't've": "should not have","so've": "so have",
                     "that'd": "that would","that'd've": "that would have", "there'd": "there would",
                     "there'd've": "there would have", "they'd": "they would",
                     "they'd've": "they would have","they'll": "they will",
                     "they'll've": "they will have", "they're": "they are","they've": "they have",
                     "to've": "to have","wasn't": "was not","we'd": "we would",
                     "we'd've": "we would have","we'll": "we will","we'll've": "we will have",
                     "we're": "we are","we've": "we have", "weren't": "were not","what'll": "what will",
                     "what'll've": "what will have","what're": "what are", "what've": "what have",
                     "when've": "when have","where'd": "where did", "where've": "where have",
                     "who'll": "who will","who'll've": "who will have","who've": "who have",
                     "why've": "why have","will've": "will have","won't": "will not",
                     "won't've": "will not have", "would've": "would have","wouldn't": "would not",
                     "wouldn't've": "would not have","y'all": "you all", "y'all'd": "you all would",
                     "y'all'd've": "you all would have","y'all're": "you all are",
                     "y'all've": "you all have", "you'd": "you would","you'd've": "you would have",
                     "you'll": "you will","you'll've": "you will have", "you're": "you are",
                     "you've": "you have" ,  "Today’s":" Today is"}


df['content']=df['content'].replace(contractions_dict, regex=True)
# Remplacer les contractions dans un texte
def replace_words_in_text(text, replace_dict):
    
    return ' '.join([replace_dict.get(word, word) for word in text.split()])

# Appliquer le remplacement de contractions à toutes les colonnes du DataFrame
def replace_words_in_dataframe(df, replace_dict):
    for col in df.select_dtypes(include=['object']).columns:
        
       df[col] = df[col].apply(lambda x: replace_words_in_text(x, replace_dict))
    return df
df_replaced = replace_words_in_dataframe(df, contractions_dict)
print(df_replaced)
# Out:
#        Unnamed: 0                                            content
# 0               0  RT @DoreenCaven: I fear that people watch so m...
# 1               1  RT @KaroroMitchelle: Not about to spend the re...
# 2               2  RT @awanz05: Urgent Appeal for Action I cannot...
# 3               5  RT @ShivanyaSitole: Supreme God Kabir God Kabi...
# 4               6  RT @patriciaflima12: “Trust me, I'm not leavin...
# ...           ...                                                ...
# 12301       18573                                         catasters:
# 12302       18574  zegalba:Mount Fuji seen from the International...
# 12303       18575  thehopefulquotes: “Loving someone means taking...
# 12304       18576  perfectfeelings: “I want to talk about what ha...
# 12305       18577  perfeqt: “Always end the day with a positive t...
#
# [12306 rows x 2 columns]

# %%
#Supprimer les signes de ponctuation et convertir le texte en minuscules.

##\nMotivationalMondays       M o t i v a t i o n  ===== motivation 
import string
def punct_word(text) :   
    return "".join([i.lower() for i in text if i not in string.punctuation])
df_replaced["content"]= df_replaced["content"].apply(punct_word)
df_replaced["content"][0]
# Out:
# 'rt doreencaven i fear that people watch so many performative displays of romantic affection especially in a time of social media couples…'

# %%
# Extraire et afficher les émojis et leur descriptions  .
import demoji
emoji_result = df_replaced["content"].apply(lambda x: demoji.findall(x))
for item in emoji_result.tolist():
    if  item:
        print(item)
# Out:
# {'🌷': 'tulip', '🙇\u200d♂️': 'man bowing', '❣️': 'heart exclamation'}
# {'💥': 'collision'}
# {'👪': 'family', '🙏🏽': 'folded hands: medium skin tone'}
# {'💥': 'collision'}
# {'🍨': 'ice cream', '🔥': 'fire'}
# {'😏': 'smirking face'}
# {'❤️': 'red heart', '😄': 'grinning face with smiling eyes', '🤩': 'star-struck'}
# {'🆘': 'SOS button'}
# {'😩': 'weary face', '😣': 'persevering face'}
# {'🧠': 'brain', '🤯': 'exploding head'}
# {'🤣': 'rolling on the floor laughing'}
# {'🙃': 'upside-down face', '🙂': 'slightly smiling face'}
# {'✨': 'sparkles'}
# {'😁': 'beaming face with smiling eyes'}
# {'🙌🏼': 'raising hands: medium-light skin tone'}
# {'💬': 'speech balloon'}
# {'🎉': 'party popper', '❤️': 'red heart', '👉': 'backhand index pointing right'}
# {'😐': 'neutral face'}
# {'😃': 'grinning face with big eyes'}
# {'😳': 'flushed face'}
# {'😳': 'flushed face', '😢': 'crying face'}
# {'⛅': 'sun behind cloud', '😣': 'persevering face', '😌': 'relieved face', '🌸': 'cherry blossom', '😞': 'disappointed face'}
# ...

# %%
#Remplace les émojis  par leurs descriptions textuelles.
import emoji
df_replaced["content"]=df_replaced["content"].astype(str).apply(lambda x: emoji.demojize(x, delimiters=(' ', ' ')))

# %%
from nltk.tokenize import word_tokenize
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
# Téléchargement des ressources spécifiques de la bibliothèque NLTK
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Charger les stopwords en anglais
stop_words = set(stopwords.words('english'))
# Créer une instance du lemmatiseur WordNet pour convertir les mots en leur forme de base
lemmatizer = WordNetLemmatizer()
def remove(text):
    # Diviser le texte en une liste de mots
    words = word_tokenize(text)
    # Filtrer les mots pour exclure ceux qui sont dans la liste des stopwords
    filtered_words = [word for word in words if word.lower() not in stop_words]
    # Trouver la forme de base de ces mots
    lemmatized_words = [lemmatizer.lemmatize(word.lower()) for word in filtered_words]
    # Filtrer les mots pour conserver uniquement ceux qui sont alphabétiques
    checked_words = [word for word in lemmatized_words if word.isalpha()]
    return ' '.join(checked_words)
# Appliquer la fonction à la colonne 'content' de la DataFrame
df_replaced['content'] = df_replaced['content'].apply(remove)
# Afficher le résultat
df_replaced.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#    Unnamed: 0                                            content
# 0           0  rt doreencaven fear people watch many performa...
# 1           1  rt karoromitchelle spend rest trapped sneaky l...
# 2           2  rt urgent appeal action express much feel man ...
# 3           5  rt shivanyasitole supreme god kabir god kabir ...
# ...

# %%
df_replaced.to_csv('dataset_depression_finale.csv' ,index=False)
