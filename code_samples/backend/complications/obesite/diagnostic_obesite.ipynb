# %% [markdown]
# ## Récupération des données

# %%
import pandas as pd 
data = pd.read_csv('../../datasets/datasets_complications/dataset_obesite.csv')
data.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
data['TUE'].unique()
# Out:
# array([1.      , 0.      , 2.      , ..., 0.646288, 0.586035, 0.714137])

# %% [markdown]
# ## Nettoyage et Exploration des données

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Filtrer les femmes
femmes_data = data[data["Gender"] == "Female"]

# Grouper les poids par catégorie de NObeyesdad
grouped = femmes_data.groupby("NObeyesdad")["Weight"]

# Calculer la moyenne du poids par niveau d'obésité
mean_weights = grouped.mean().sort_values()

# Tracer le diagramme à barres
plt.figure(figsize=(10, 6))
plt.bar(mean_weights.index, mean_weights.values, color="lightcoral", edgecolor="black")

plt.xlabel("Niveau d'obésité")
plt.ylabel("Poids moyen (kg)")
plt.title("Poids moyen des femmes selon le niveau d'obésité")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
if

# %%
data['NObeyesdad'].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
val_cible = data['NObeyesdad'].value_counts()
val_cible
# Out:
# NObeyesdad
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (2111, 17)

# %%
data.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
data.dtypes
# Out:
# Gender                             object
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# NObeyesdad                         object
# dtype: object

# %%
data.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=2111, step=1)

# %%
data.rename(columns={"NObeyesdad": "Obesity_Level"}, inplace=True)

# %%
data
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
val_cible = data['Obesity_Level'].unique()
val_cible
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
import pandas as pd

# Création du tableau des niveaux d'obésité
obesity_levels = {
    "Obesity_Level": [
        "Insufficient_Weight",
        "Normal_Weight",
        "Overweight_Level_I",
        "Overweight_Level_II",
        "Obesity_Type_I",
        "Obesity_Type_II",
        "Obesity_Type_III"
    ],
    "Description": [
        "Underweight (BMI < 18.5)",
        "Normal weight (BMI 18.5 - 24.9)",
        "Slight overweight (BMI 25 - 27.4)",
        "Moderate overweight (BMI 27.5 - 29.9)",
        "Obesity Type I (BMI 30 - 34.9)",
        "Obesity Type II (BMI 35 - 39.9)",
        "Obesity Type III (BMI ≥ 40)"
    ]
}

df_obesity = pd.DataFrame(obesity_levels)
df_obesity
# Out:
#          Obesity_Level                            Description
# 0  Insufficient_Weight               Underweight (BMI < 18.5)
# 1        Normal_Weight        Normal weight (BMI 18.5 - 24.9)
# 2   Overweight_Level_I      Slight overweight (BMI 25 - 27.4)
# 3  Overweight_Level_II  Moderate overweight (BMI 27.5 - 29.9)
# 4       Obesity_Type_I         Obesity Type I (BMI 30 - 34.9)
# 5      Obesity_Type_II        Obesity Type II (BMI 35 - 39.9)
# 6     Obesity_Type_III            Obesity Type III (BMI ≥ 40)

# %%
import matplotlib.pyplot as plt

# Affecter une couleur par catégorie (juste pour le style)
colors = ['#87CEEB', '#98FB98', '#FFD700', '#FFA500', '#FF6347', '#FF4500', '#8B0000']

# Graphique en barres
plt.figure(figsize=(10, 6))
plt.bar(df_obesity["Obesity_Level"], range(len(df_obesity)), color=colors)
plt.title("Obesity Levels", fontsize=16)
plt.xlabel("Obesity Level", fontsize=12)
plt.ylabel("Severity (Low to High)", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
data.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# Obesity_Level                     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(24)

# %%
data = data.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data_cols = data.columns
print(data_cols)
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'Obesity_Level'],
#       dtype='object')

# %%
data_cols = data.columns
for col in data_cols : 
    print(f' {col} : {data[col].unique()}')
# Out:
#  Gender : ['Female' 'Male']
#  Age : [21.       23.       27.       ... 22.524036 24.361936 23.664709]
#  Height : [1.62     1.52     1.8      ... 1.752206 1.73945  1.738836]
#  Weight : [ 64.        56.        77.       ... 133.689352 133.346641 133.472641]
#  family_history_with_overweight : ['yes' 'no']
#  FAVC : ['no' 'yes']
#  FCVC : [2.       3.       1.       2.450218 2.880161 2.00876  2.596579 2.591439
#  2.392665 1.123939 2.027574 2.658112 2.88626  2.714447 2.750715 1.4925
#  2.205439 2.059138 2.310423 2.823179 2.052932 2.596364 2.767731 2.815157
#  2.737762 2.568063 2.524428 2.971574 1.0816   1.270448 1.344854 2.959658
#  2.725282 2.844607 2.44004  2.432302 2.592247 2.449267 2.929889 2.015258
#  1.031149 1.592183 1.21498  1.522001 2.703436 2.362918 2.14084  2.5596
#  2.336044 1.813234 2.724285 2.71897  1.133844 1.757466 2.979383 2.204914
#  2.927218 2.88853  2.890535 2.530066 2.241606 1.003566 2.652779 2.897899
# ...

# %%
data = data[data['Gender'] == "Female"]

# %%
data['Gender'].unique()
# Out:
# array(['Female'], dtype=object)

# %%
data = data.drop(columns=['Gender'])

# %%
data.shape
# Out:
# (1035, 16)

# %%
# Séparer les colonnes numériques et catégoriques
cat_cols = data.select_dtypes(include=object).columns
data_cols = cat_cols 
for col in data_cols : 
    print(f' {col} : {data[col].unique()}')
# Out:
#  family_history_with_overweight : ['yes' 'no']
#  FAVC : ['no' 'yes']
#  CAEC : ['Sometimes' 'Frequently' 'Always' 'no']
#  SMOKE : ['no' 'yes']
#  SCC : ['no' 'yes']
#  CALC : ['no' 'Sometimes' 'Frequently']
#  MTRANS : ['Public_Transportation' 'Motorbike' 'Automobile' 'Walking']
#  Obesity_Level : ['Normal_Weight' 'Overweight_Level_II' 'Obesity_Type_I'
#  'Overweight_Level_I' 'Insufficient_Weight' 'Obesity_Type_II'
#  'Obesity_Type_III']

# %%
val_cible = data['Obesity_Level'].value_counts()
val_cible
# Out:
# Obesity_Level
# Obesity_Type_III       323
# Insufficient_Weight    169
# Obesity_Type_I         156
# Overweight_Level_I     145
# Normal_Weight          137
# Overweight_Level_II    103
# Obesity_Type_II          2
# Name: count, dtype: int64

# %%
data = data[data["Obesity_Level"] != "Obesity_Type_II"]

# %%
val_cible = data['Obesity_Level'].value_counts()
val_cible
# Out:
# Obesity_Level
# Obesity_Type_III       323
# Insufficient_Weight    169
# Obesity_Type_I         156
# Overweight_Level_I     145
# Normal_Weight          137
# Overweight_Level_II    103
# Name: count, dtype: int64

# %%
data.dtypes
# Out:
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# Obesity_Level                      object
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Afficher les types de colonnes
print(data.dtypes)

# Garder uniquement les colonnes numériques (optionnel : supprimer les identifiants)
data_numeric =  data.select_dtypes(include=['int64', 'float64'])
# Taille de la figure
plt.figure(figsize=(15, 8))

# Boxplot pour toutes les variables numériques
sns.boxplot(data=data_numeric, orient='h')

plt.title("Boxplot des variables numériques du dataset Obesité")
plt.tight_layout()
plt.show()
# Out:
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# Obesity_Level                      object
# dtype: object

# %%
if

# %%
data_cols = ['family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC', 'CALC', 'MTRANS']
for col in data_cols : 
    print(f' {col} : {data[col].unique()}')
# Out:
#  family_history_with_overweight : ['yes' 'no']
#  FAVC : ['no' 'yes']
#  CAEC : ['Sometimes' 'Frequently' 'Always' 'no']
#  SMOKE : ['no' 'yes']
#  SCC : ['no' 'yes']
#  CALC : ['no' 'Sometimes' 'Frequently']
#  MTRANS : ['Public_Transportation' 'Motorbike' 'Automobile' 'Walking']

# %%
from sklearn.preprocessing import LabelEncoder

# Encoder les colonnes catégoriques avec LabelEncoder
label_encoders = {}
for col in cat_cols:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col].astype(str))  # Convertir NaN en string "nan"
    label_encoders[col] = le

# %%
data.dtypes
# Out:
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight      int64
# FAVC                                int64
# FCVC                              float64
# NCP                               float64
# CAEC                                int64
# SMOKE                               int64
# CH2O                              float64
# SCC                                 int64
# FAF                               float64
# TUE                               float64
# CALC                                int64
# MTRANS                              int64
# Obesity_Level                       int64
# dtype: object

# %%
data['Obesity_Level'].unique()
# Out:
# array([1, 5, 2, 4, 0, 3])

# %%
print(le.classes_)
# Out:
# ['Insufficient_Weight' 'Normal_Weight' 'Obesity_Type_I' 'Obesity_Type_III'
#  'Overweight_Level_I' 'Overweight_Level_II']

# %%
target_col = 'Obesity_Level'
le = label_encoders[target_col]

# Afficher la correspondance classe -> code
for i, class_name in enumerate(le.classes_):
    print(f"{class_name} => {i}")
# Out:
# Insufficient_Weight => 0
# Normal_Weight => 1
# Obesity_Type_I => 2
# Obesity_Type_III => 3
# Overweight_Level_I => 4
# Overweight_Level_II => 5

# %%
# Séparer les colonnes numériques et catégoriques
data_cols = data.columns
for col in data_cols : 
    print(f' {col} : {data[col].unique()}')
# Out:
#  Age : [21.       23.       22.       29.       30.       52.       31.
#  24.       20.       17.       19.       38.       25.       18.
#  15.       61.       34.       36.       27.       32.       35.
#  40.       45.       33.       41.       26.       51.       28.
#  39.       16.       37.       25.196214 18.503343 21.853826 21.90012
#  18.306615 21.849705 21.02497  22.038327 21.243142 22.142432 21.962426
#  21.491055 22.717943 23.501249 18.535075 20.254534 20.225396 19.86997
#  20.147114 21.996523 21.376426 19.724106 18.871794 18.766033 18.540535
#  19.88036  19.717249 19.633898 20.406871 19.058511 18.827008 19.314964
#  29.970445 32.383858 24.163526 17.082867 17.000433 16.270434 22.377998
#  20.954955 22.991668 19.300435 17.065445 19.084967 18.024853 19.833682
#  17.767432 19.504696 19.950605 22.926352 21.785351 17.402028 18.48207
#  18.53084  19.94814  20.400053 19.010211 19.091346 19.773303 19.483036
# ...

# %%
import numpy as np
np.set_printoptions(suppress=True)

# %%
data_cols = data.columns
for col in data_cols : 
    print(f' {col} : {data[col].unique()}')
# Out:
#  Age : [21.       23.       22.       29.       30.       52.       31.
#  24.       20.       17.       19.       38.       25.       18.
#  15.       61.       34.       36.       27.       32.       35.
#  40.       45.       33.       41.       26.       51.       28.
#  39.       16.       37.       25.196214 18.503343 21.853826 21.90012
#  18.306615 21.849705 21.02497  22.038327 21.243142 22.142432 21.962426
#  21.491055 22.717943 23.501249 18.535075 20.254534 20.225396 19.86997
#  20.147114 21.996523 21.376426 19.724106 18.871794 18.766033 18.540535
#  19.88036  19.717249 19.633898 20.406871 19.058511 18.827008 19.314964
#  29.970445 32.383858 24.163526 17.082867 17.000433 16.270434 22.377998
#  20.954955 22.991668 19.300435 17.065445 19.084967 18.024853 19.833682
#  17.767432 19.504696 19.950605 22.926352 21.785351 17.402028 18.48207
#  18.53084  19.94814  20.400053 19.010211 19.091346 19.773303 19.483036
# ...

# %%
# family_history_with_overweight , FAVC , SMOKE , SCC , CALC , MTRANS , Obesity_Level 

cols_cats = ['family_history_with_overweight', 'FAVC', 'CAEC' ,'SMOKE', 'SCC', 'CALC', 'MTRANS', 'Obesity_Level']

for col in cols_cats : 
    print(f' {col} : {data[col].unique()}')
# Out:
#  family_history_with_overweight : [1 0]
#  FAVC : [0 1]
#  CAEC : [2 1 0 3]
#  SMOKE : [0 1]
#  SCC : [0 1]
#  CALC : [2 1 0]
#  MTRANS : [2 1 0 3]
#  Obesity_Level : [1 5 2 4 0 3]

# %%
# Convertir 'Age', 'Height', et 'Weight' en entiers
data['Age'] = data['Age'].astype(int)
# Arrondir à 2 chiffres après la virgule
cols_to_round = ['Height' , 'Weight',  'TUE', 'FAF', 'CH2O']
for col in cols_to_round:
    data[col] = data[col].round(2)
# Vérifier les colonnes après conversion
print(data[['Height' , 'Weight',  'TUE', 'FAF', 'CH2O']].head())
# Out:
#     Height  Weight  TUE  FAF  CH2O
# 0     1.62    64.0  1.0  0.0   2.0
# 1     1.52    56.0  0.0  3.0   3.0
# 6     1.50    55.0  0.0  1.0   2.0
# 11    1.72    80.0  1.0  2.0   2.0
# 15    1.70    66.0  1.0  2.0   2.0

# %%
data_cols = data.columns
for col in data_cols : 
    print(f' {col} : {data[col].unique()}')
# Out:
#  Age : [21 23 22 29 30 52 31 24 20 17 19 38 25 18 15 61 34 36 27 32 35 40 45 33
#  41 26 51 28 39 16 37 42 43 47]
#  Height : [1.62 1.52 1.5  1.72 1.7  1.53 1.71 1.65 1.69 1.6  1.58 1.77 1.56 1.75
#  1.67 1.66 1.55 1.61 1.64 1.63 1.57 1.68 1.74 1.73 1.48 1.59 1.54 1.8
#  1.45 1.51 1.76 1.84 1.82 1.83 1.79 1.78 1.46 1.49 1.81]
#  Weight : [ 64.    56.    55.    80.    66.    78.    82.    70.    87.    60.
#   52.    68.    76.    65.    49.    48.    88.    75.    50.    54.5
#   44.    67.    57.    69.    45.    90.    58.    42.    63.    51.
#   62.    86.    85.    61.    53.    59.    72.    79.    77.    59.8
#   83.    40.   102.    42.3   66.5   47.    91.    73.    71.    39.
#  112.    53.8   51.5   53.5  104.57 126.67 110.79 137.8  165.06 133.03
#  111.49 104.83 133.96  51.15  49.87  51.97  44.85  42.85  43.92  43.09
#   44.58  42.34  42.1   41.32  44.64  50.89  50.83  41.45  41.89  41.4
#   49.74  49.66  49.04  50.29  53.7   51.44  49.84  49.93  49.52  46.66
# ...

# %%
data.dtypes
# Out:
# Age                                 int64
# Height                            float64
# Weight                            float64
# family_history_with_overweight      int64
# FAVC                                int64
# FCVC                              float64
# NCP                               float64
# CAEC                                int64
# SMOKE                               int64
# CH2O                              float64
# SCC                                 int64
# FAF                               float64
# TUE                               float64
# CALC                                int64
# MTRANS                              int64
# Obesity_Level                       int64
# dtype: object

# %%
val_cible = data['Obesity_Level'].value_counts()
val_cible
# Out:
# Obesity_Level
# 3    323
# 0    169
# 2    156
# 4    145
# 1    137
# 5    103
# Name: count, dtype: int64

# %% [markdown]
# ### Analyse de corrélation

# %% [markdown]
# Pourquoi  ?
# Identifier les variables redondantes (très corrélées entre elles) : ressemblent trop (ex : poids et BMI)
#
# Éviter le sur-apprentissage en supprimant les variables redondantes :  trop similaires.
#
# Sélectionner les meilleures variables pour entraîner un modèle performant

# %%
# 1) Identifier les variables redondantes (très corrélées entre elles)
import seaborn as sns
import matplotlib.pyplot as plt

# Matrice de corrélation
corr_matrix = data.corr()

# Affichage visuel
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Matrice de corrélation")
plt.show()

# %% [markdown]
# ### Supprimer les variables fortement corrélées

# %%
# 2) Éviter le sur-apprentissage en supprimant les variables trop similaires
# Supprimer une des deux variables très corrélées (> 0.85)
# On crée une liste des colonnes à supprimer

to_drop = set()
threshold = 0.85

for i in range(len(corr_matrix.columns)):
    for j in range(i):
        if corr_matrix.iloc[i, j] > threshold:
            colname = corr_matrix.columns[i]
            to_drop.add(colname)

print("Variables à supprimer :", to_drop)

# Suppression des colonnes sélectionnées
df_cleaned = data.drop(columns=to_drop)
# Out:
# Variables à supprimer : set()

# %%
df_cleaned.columns
# Out:
# Index(['Age', 'Height', 'Weight', 'family_history_with_overweight', 'FAVC',
#        'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE', 'CALC',
#        'MTRANS', 'Obesity_Level'],
#       dtype='object')

# %%
df_cleaned.shape
# Out:
# (1033, 16)

# %%
# data = df_cleaned

# %%
data.shape
# Out:
# (1033, 16)

# %%
data
# Out:
#       Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  NCP  \
# 0      21    1.62   64.00                               1     0   2.0  3.0
# 1      21    1.52   56.00                               1     0   3.0  3.0
# 6      23    1.50   55.00                               1     1   3.0  3.0
# 11     21    1.72   80.00                               1     1   2.0  3.0
# 15     22    1.70   66.00                               1     0   3.0  3.0
# ...   ...     ...     ...                             ...   ...   ...  ...
# 2106   20    1.71  131.41                               1     1   3.0  3.0
# 2107   21    1.75  133.74                               1     1   3.0  3.0
# 2108   22    1.75  133.69                               1     1   3.0  3.0
# 2109   24    1.74  133.35                               1     1   3.0  3.0
# 2110   23    1.74  133.47                               1     1   3.0  3.0
#
# ...

# %%
if
# Out:
#   Cell In[49], line 1
#     if
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Modélisation

# %% [markdown]
# ### 1) Division de données en : Données d'entrées (Input) et Données de Sorties (Output)

# %%
x = data.drop('Obesity_Level' , axis=1)
x_list = list(x.columns)
x = np.array(x)
y = data['Obesity_Level']
y =np.array(y)

print(x_list)
print(x)
print(y)
# Out:
# ['Age', 'Height', 'Weight', 'family_history_with_overweight', 'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE', 'CALC', 'MTRANS']
# [[ 21.     1.62  64.   ...   1.     2.     2.  ]
#  [ 21.     1.52  56.   ...   0.     1.     2.  ]
#  [ 23.     1.5   55.   ...   0.     1.     1.  ]
#  ...
#  [ 22.     1.75 133.69 ...   0.65   1.     2.  ]
#  [ 24.     1.74 133.35 ...   0.59   1.     2.  ]
#  [ 23.     1.74 133.47 ...   0.71   1.     2.  ]]
# [1 1 1 ... 3 3 3]

# %% [markdown]
# ### 2) Division de données en : Données d'Apprentissage (Data Training : 90%) et Données de Test (Data Testing : 10%)

# %%
data.shape
# Out:
# (1033, 16)

# %%
from sklearn.model_selection import train_test_split 

x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.1 , random_state=40)

print('Training Data x : ' , x_train.shape)
print('Training Data y : ' ,y_train.shape)
print('Testing Data x : ' , x_test.shape)
print('Testing Data y : ' ,y_test.shape)
# Out:
# Training Data x :  (929, 15)
# Training Data y :  (929,)
# Testing Data x :  (104, 15)
# Testing Data y :  (104,)

# %%
from sklearn.utils import shuffle

x_test, y_test = shuffle(x_test, y_test, random_state=42)

x_final_test= x_test[:7]
y_final_test = y_test[:7]

x_test= x_test[7:]
y_test = y_test[7:]

print("Testing Data:", x_test.shape, y_test.shape)
print("Final Testing Data:", x_final_test.shape, y_final_test.shape)
print(y_final_test)
# Out:
# Testing Data: (97, 15) (97,)
# Final Testing Data: (7, 15) (7,)
# [3 3 0 4 0 2 4]

# %% [markdown]
# ### 3) Comparaison des algorithmes de Machine Learning :
# * Gradient Boosting
# * XGBoost
# * Random Forest

# %% [markdown]
# on Choisit des Algorithmes de classification comme (Gradient Boosting classifier - XGBoost classifier - Random Forest classifier) car :
# on a un probléme de classification puisque la variable cible (Target) est catégorielle

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
import xgboost as xgb
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score , roc_curve, auc, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %% [markdown]
# #### a) Gradient Boosting

# %% [markdown]
# ##### * Créer et Entraîner le modéle

# %%
# Créer le modèle Gradient Boosting

#Avant GridSearch 
model_gradientBoosting = GradientBoostingClassifier(
    
    n_estimators=100, 
    learning_rate=0.1, 
    max_depth=3, 
    random_state=42
)




# Entraîner le modèle
model_gradientBoosting.fit(x_train, y_train)

# Prédiction
y_pred = model_gradientBoosting.predict(x_test)

# %% [markdown]
# ##### * Évaluer la performance du modèle par le calcul des métriques d'évaluation

# %% [markdown]
# ##### -- Matrice de confusion

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt


from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Calculer la matrice de confusion
cm = confusion_matrix(y_test, y_pred)

# Afficher la matrice avec les bons labels pour les 3 classes
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=[ "Obesity_Type_III", "Insufficient_Weight", "Obesity_Type_I", "Overweight_Level_I", "Normal_Weight", 
    "Overweight_Level_II"]
)

# Tracer la matrice

disp.plot(cmap="Blues")
plt.title('Matrice de Confusion')
plt.show()

# %% [markdown]
# ##### -- Métriques :
# * Accuracy
# * Recall
# * Precision
# * F1-Score
# * AUC-ROC

# %%
# Calculer les métriques
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred , average=None)
precision = precision_score(y_test, y_pred , average=None)
f1 = f1_score(y_test, y_pred , average=None) 
# AUC-ROC pour chaque classe (multi-classe)
y_proba = model_gradientBoosting.predict_proba(x_test)  # Probabilités par classe

auc_roc = roc_auc_score(y_test, y_proba, average=None, multi_class='ovr')

# Afficher les résultats
print(f'Accuracy: {accuracy}')
print(f'Recall: {recall}')
print(f'Precision: {precision}')
print(f'F1-Score: {f1}')
print(f'AUC-ROC: {auc_roc}')
# Out:
# Accuracy: 0.9896907216494846
# Recall: [1.         1.         0.92307692 1.         1.         1.        ]
# Precision: [1.         1.         1.         1.         0.90909091 1.        ]
# F1-Score: [1.         1.         0.96       1.         0.95238095 1.        ]
# AUC-ROC: [1.         1.         0.99908425 1.         0.99885057 1.        ]

# %% [markdown]
# ### Sélection des meilleures variables (feature selection)

# %% [markdown]
# pour entraîner ton modèle juste avec les colonnes utiles.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb

def val_importance(model, feature_names, top_n=12):
    """Affiche et retourne les top N features les plus importantes du modèle XGBoost."""

    importance_val = model.feature_importances_
    feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importance_val})
    feature_importance_df = feature_importance_df.sort_values(by="Importance", ascending=False)

    # Affichage graphique
    plt.figure(figsize=(8, 6))
    sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='Blues_r')
    plt.title("Les Features (Caractéristiques) Importantes")
    plt.xlabel("Valeur d'Importance")
    plt.ylabel("Features (Caractéristiques)")
    plt.show()

    # Top N
    top_features_df = feature_importance_df.head(top_n)
    print(f"Top {top_n} caractéristiques les plus importantes :\n")
    print(top_features_df)

    # Retourner la liste des noms des top features
    return top_features_df['Feature'].tolist()

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score
from sklearn.preprocessing import label_binarize
import numpy as np
import pandas as pd

# Si x_train est un ndarray, convertis-le en DataFrame
x_train = pd.DataFrame(x_train, columns=x_list)
x_test = pd.DataFrame(x_test, columns=x_list)

# Étape 1 : Entraînement initial avec Gradient Boosting
# model_gradientBoosting_top = GradientBoostingClassifier(
#     learning_rate=0.1,
#     n_estimators=100,
#     max_depth=3,
#     subsample=0.7,
#     random_state=42
# )
# model_gb.fit(x_train, y_train)

# Étape 2 : Obtenir les top features (fonction personnalisée `val_importance`)
top_features_list = val_importance(model_gb, x_train.columns)

# Étape 3 : Sélectionner les données avec les top features
x_train_top_features = x_train[top_features_list]
x_test_top_features = x_test[top_features_list]

# Étape 4 : Réentraîner le modèle avec les top features
model_gradientBoosting_top = GradientBoostingClassifier(
    learning_rate=0.1,
    n_estimators=100,
    max_depth=3,
    subsample=0.7,
    random_state=42
)
model_gradientBoosting_top.fit(x_train_top_features, y_train)

# Étape 5 : Prédiction et évaluation
y_pred = model_gradientBoosting_top.predict(x_test_top_features)

# Métriques
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred, average='macro')
precision = precision_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')

# Pour AUC-ROC
y_prob = model_gb_top.predict_proba(x_test_top_features)
classes = np.unique(y_test)
y_test_binarized = label_binarize(y_test, classes=classes)
auc_roc = roc_auc_score(y_test_binarized, y_prob, average='macro', multi_class='ovr')

# Affichage des résultats
print(f'Accuracy: {accuracy}')
print(f'Recall: {recall}')
print(f'Precision: {precision}')
print(f'F1-Score: {f1}')
print(f'AUC-ROC: {auc_roc}')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5632\2475694210.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='Blues_r')
# Top 12 caractéristiques les plus importantes :
#
#    Feature  Importance
# 2   Weight    0.703623
# 1   Height    0.132207
# 5     FCVC    0.037065
# 0      Age    0.027493
# 4     FAVC    0.018290
# 13    CALC    0.015877
# 9     CH2O    0.013181
# 11     FAF    0.013120
# 12     TUE    0.008602
# 7     CAEC    0.008044
# 6      NCP    0.006846
# 10     SCC    0.005923
# Accuracy: 0.9896907216494846
# Recall: 0.9871794871794872
# Precision: 0.9848484848484849
# F1-Score: 0.9853968253968254
# AUC-ROC: 1.0

# %% [markdown]
# ##### -- Courbe ROC-AUC

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
from itertools import cycle
import numpy as np

# 1. Définir toutes les classes possibles et binariser
classes = [0, 1, 2, 3, 4, 5]  # classes connues
n_classes = len(classes)
y_test_bin = label_binarize(y_test, classes=classes)
y_pred_proba = model_gradientBoosting.predict_proba(x_test)  # shape: (n_samples, n_classes)

# 2. Initialiser les dictionnaires
fpr = dict()
tpr = dict()
roc_auc = dict()
colors = cycle(['blue', 'orange', 'green', 'red', 'purple', 'brown'])

# 3. Calculer FPR, TPR et AUC pour chaque classe
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_pred_proba[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 4. Tracer les courbes ROC
plt.figure(figsize=(10, 7))
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label=f'Classe {classes[i]} (AUC = {roc_auc[i]:.2f})')

# Courbe aléatoire
plt.plot([0, 1], [0, 1], 'k--', lw=2)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taux de Faux Positifs (FPR)')
plt.ylabel('Taux de Vrais Positifs (TPR)')
plt.title('Courbes ROC Multi-Classe')
plt.legend(loc='lower right')
plt.grid()
plt.show()
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   warnings.warn(

# %% [markdown]
# #### b) XGBoost

# %% [markdown]
# ##### * Créer et Entraîner le modéle

# %%
# Créer le modèle XGBoost
# Avant GridSearch 
model_xgboost = xgb.XGBClassifier(

   n_estimators =100 ,
   learning_rate=0.1 , 
   max_depth=3 , 
   random_state=42
)

# model_xgboost = xgb.XGBClassifier(
#    random_state=42 , 
#    colsample_bytree = 0.7,
#    gamma = 0,
#    learning_rate = 0.01,
#    max_depth = 5,
#    n_estimators = 50,
#    subsample = 0.7
# )

#Aprés GridSearch 
# model_xgboost = xgb.XGBClassifier(
#    random_state=42 ,
#    colsample_bytree = 1.0 ,
#    gamma = 0 ,
#    learning_rate = 0.1 ,
#    max_depth = 3 ,
#    n_estimators = 100 ,
#    subsample = 0.7
# )



# Entraîner le modèle
model_xgboost.fit(x_train, y_train)

# Prédiction
y_pred = model_xgboost.predict(x_test)

# %% [markdown]
# ##### * Évaluer la performance du modèle par le calcul des métriques d'évaluation

# %% [markdown]
# ##### -- Matrice de confusion

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt


from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Calculer la matrice de confusion
cm = confusion_matrix(y_test, y_pred)

# Afficher la matrice avec les bons labels pour les 3 classes
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=[ "Obesity_Type_III", "Insufficient_Weight", "Obesity_Type_I", "Overweight_Level_I", "Normal_Weight", 
    "Overweight_Level_II"]
)

# Tracer la matrice

disp.plot(cmap="Blues")
plt.title('Matrice de Confusion')
plt.show()

# %% [markdown]
# ##### -- Métriques :
# * Accuracy
# * Recall
# * Precision
# * F1-Score
# * AUC-ROC

# %%
# Calculer les métriques
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred , average=None)
precision = precision_score(y_test, y_pred , average=None)
f1 = f1_score(y_test, y_pred , average=None) 
# AUC-ROC pour chaque classe (multi-classe)
y_proba = model_xgboost.predict_proba(x_test)  # Probabilités par classe

auc_roc = roc_auc_score(y_test, y_proba, average=None, multi_class='ovr')

# Afficher les résultats
print(f'Accuracy: {accuracy}')
print(f'Recall: {recall}')
print(f'Precision: {precision}')
print(f'F1-Score: {f1}')
print(f'AUC-ROC: {auc_roc}')
# Out:
# Accuracy: 0.9896907216494846
# Recall: [1.         1.         1.         1.         1.         0.92307692]
# Precision: [1.         1.         1.         1.         0.90909091 1.        ]
# F1-Score: [1.         1.         1.         1.         0.95238095 0.96      ]
# AUC-ROC: [1. 1. 1. 1. 1. 1.]

# %% [markdown]
# ##### -- Courbe ROC-AUC

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
from itertools import cycle
import numpy as np

# 1. Définir toutes les classes possibles et binariser
classes = [0, 1, 2, 3, 4, 5]  # classes connues
n_classes = len(classes)
y_test_bin = label_binarize(y_test, classes=classes)
y_pred_proba = model_gradientBoosting.predict_proba(x_test)  # shape: (n_samples, n_classes)

# 2. Initialiser les dictionnaires
fpr = dict()
tpr = dict()
roc_auc = dict()
colors = cycle(['blue', 'orange', 'green', 'red', 'purple', 'brown'])

# 3. Calculer FPR, TPR et AUC pour chaque classe
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_pred_proba[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 4. Tracer les courbes ROC
plt.figure(figsize=(10, 7))
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label=f'Classe {classes[i]} (AUC = {roc_auc[i]:.2f})')

# Courbe aléatoire
plt.plot([0, 1], [0, 1], 'k--', lw=2)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taux de Faux Positifs (FPR)')
plt.ylabel('Taux de Vrais Positifs (TPR)')
plt.title('Courbes ROC Multi-Classe')
plt.legend(loc='lower right')
plt.grid()
plt.show()
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   warnings.warn(

# %% [markdown]
# #### c) Random Forest

# %% [markdown]
# ##### * Créer et Entraîner le modéle

# %%
# Créer le modèle Random Forest
# Avant GridSearch
model_randomForest = RandomForestClassifier(

    n_estimators=100, 
    max_depth=5, 
    random_state=42

    
    )
# Aprés GridSerach
# model_randomForest = RandomForestClassifier(
#    random_state=42, 
#    max_depth = None,
#    max_features = "sqrt",
#    min_samples_leaf = 1,
#    min_samples_split = 2,
#    n_estimators = 50
#     )


# Entraîner le modèle
model_randomForest.fit(x_train, y_train)

# Prédiction
y_pred = model_randomForest.predict(x_test)

# %% [markdown]
# ##### * Évaluer la performance du modèle par le calcul des métriques d'évaluation

# %% [markdown]
# ##### -- Matrice de confusion

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt


from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Calculer la matrice de confusion
cm = confusion_matrix(y_test, y_pred)

# Afficher la matrice avec les bons labels pour les 6 classes
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=[ "Obesity_Type_III", "Insufficient_Weight", "Obesity_Type_I", "Overweight_Level_I", "Normal_Weight", 
    "Overweight_Level_II"]
)

# Tracer la matrice

disp.plot(cmap="Blues")
plt.title('Matrice de Confusion')
plt.show()

# %% [markdown]
# ##### -- Métriques :
# * Accuracy
# * Recall
# * Precision
# * F1-Score
# * AUC-ROC

# %%
# Calculer les métriques
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred , average=None)
precision = precision_score(y_test, y_pred , average=None)
f1 = f1_score(y_test, y_pred , average=None) 
# AUC-ROC pour chaque classe (multi-classe)
y_proba = model_randomForest.predict_proba(x_test)  # Probabilités par classe

auc_roc = roc_auc_score(y_test, y_proba, average=None, multi_class='ovr')

# Afficher les résultats
print(f'Accuracy: {accuracy}')
print(f'Recall: {recall}')
print(f'Precision: {precision}')
print(f'F1-Score: {f1}')
print(f'AUC-ROC: {auc_roc}')
# Out:
# Accuracy: 0.9278350515463918
# Recall: [1.         0.85714286 0.92307692 1.         1.         0.69230769]
# Precision: [1.         1.         0.8        1.         0.76923077 0.9       ]
# F1-Score: [1.         0.92307692 0.85714286 1.         0.86956522 0.7826087 ]
# AUC-ROC: [1.         0.99569707 0.98809524 1.         0.99425287 0.98717949]

# %% [markdown]
# ##### -- Courbe ROC-AUC

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
from itertools import cycle
import numpy as np

# 1. Définir toutes les classes possibles et binariser
classes = [0, 1, 2, 3, 4, 5]  # classes connues
n_classes = len(classes)
y_test_bin = label_binarize(y_test, classes=classes)
y_pred_proba = model_gradientBoosting.predict_proba(x_test)  # shape: (n_samples, n_classes)

# 2. Initialiser les dictionnaires
fpr = dict()
tpr = dict()
roc_auc = dict()
colors = cycle(['blue', 'orange', 'green', 'red', 'purple', 'brown'])

# 3. Calculer FPR, TPR et AUC pour chaque classe
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_pred_proba[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 4. Tracer les courbes ROC
plt.figure(figsize=(10, 7))
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label=f'Classe {classes[i]} (AUC = {roc_auc[i]:.2f})')

# Courbe aléatoire
plt.plot([0, 1], [0, 1], 'k--', lw=2)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taux de Faux Positifs (FPR)')
plt.ylabel('Taux de Vrais Positifs (TPR)')
plt.title('Courbes ROC Multi-Classe')
plt.legend(loc='lower right')
plt.grid()
plt.show()
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   warnings.warn(

# %% [markdown]
# ### 4) Optimisation des Hyperparamètres avec GridSearchCV pour améliorer la Performance du Modèle

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
import xgboost as xgb
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score

# Définir les modèles
models = {
    "Gradient Boosting": GradientBoostingClassifier(random_state=42),
    "XGBoost": xgb.XGBClassifier(eval_metric='logloss', use_label_encoder=False, random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42)
}

# Définir les grilles de paramètres
param_grids = {
    "Gradient Boosting": {
        'n_estimators': [50, 100],
        'learning_rate': [0.01, 0.1],
        'max_depth': [3, 5],
        'subsample': [0.7, 1.0],
        'min_samples_split': [2, 5]
    },
    "XGBoost": {
        'n_estimators': [50, 100],
        'learning_rate': [0.01, 0.1],
        'max_depth': [3, 5],
        'subsample': [0.7, 0.9],
        'colsample_bytree': [0.7, 1.0],
        'gamma': [0, 0.1]
    },
    "Random Forest": {
        'n_estimators': [50, 100],
        'max_depth': [None, 10],
        'min_samples_split': [2, 5],
        'min_samples_leaf': [1, 2],
        'max_features': ['sqrt', 'log2']
    }
}

# Fonction d'exécution
def run_grid_search(models, param_grids, x_train, y_train, x_test, y_test):
    results = {}
    for model_name, model in models.items():
        print(f"\nOptimisation de {model_name}...\n")
        
        # Grid search
        grid_search = GridSearchCV(model, param_grids[model_name], cv=3, n_jobs=-1, verbose=1)
        grid_search.fit(x_train, y_train)
        
        # Meilleur modèle
        best_model = grid_search.best_estimator_
        results[model_name] = {
            'Best Params': grid_search.best_params_,
            'Best Score': grid_search.best_score_,
            'Best Model': best_model
        }
        
        print(f"Meilleurs paramètres pour {model_name} :")
        for param, value in grid_search.best_params_.items():
            print(f"   {param} = {value}")
        print(f"Score CV : {grid_search.best_score_:.4f}")
        
        # Prédictions
        y_pred = best_model.predict(x_test)
        y_pred_proba = best_model.predict_proba(x_test)

        # Métriques multi-classes
        test_accuracy = accuracy_score(y_test, y_pred)
        test_recall = recall_score(y_test, y_pred, average='macro')
        test_precision = precision_score(y_test, y_pred, average='macro')
        test_f1 = f1_score(y_test, y_pred, average='macro')
        test_auc_roc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr', average='macro')

        print(f"\nÉvaluation sur le test set ({model_name}) :")
        # print(f"   Accuracy  : {test_accuracy:.4f}")
        print(f"   Accuracy  : {test_accuracy}")
        print(f"   Recall    : {test_recall}")
        print(f"   Précision : {test_precision}")
        print(f"   F1-Score  : {test_f1}")
        print(f"   AUC-ROC   : {test_auc_roc}\n")
    
    return results

# Appel
results = run_grid_search(models, param_grids, x_train, y_train, x_test, y_test)
# Out:
# Optimisation de Gradient Boosting...
#
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# Meilleurs paramètres pour Gradient Boosting :
#    learning_rate = 0.1
#    max_depth = 3
#    min_samples_split = 5
#    n_estimators = 100
#    subsample = 1.0
# Score CV : 0.9569
#
# Évaluation sur le test set (Gradient Boosting) :
#    Accuracy  : 0.9896907216494846
#    Recall    : 0.9871794871794872
#    Précision : 0.9848484848484849
#    F1-Score  : 0.9853968253968254
#    AUC-ROC   : 0.999808429118774
#
#
# Optimisation de XGBoost...
#
# Fitting 3 folds for each of 64 candidates, totalling 192 fits
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:158: UserWarning: [01:25:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ...

# %% [markdown]
# ### 4) Comparaison avec l'algorithme de Deep Learning :
# * Réseau de Neurones artificiels (ANN : Artificial Neural Network)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, classification_report
from tensorflow.keras.utils import to_categorical

# 1. Prétraitement des données (standardisation)
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# 2. Encodage des étiquettes (one-hot)
y_train_cat = to_categorical(y_train, num_classes=6)
y_test_cat = to_categorical(y_test, num_classes=6)

# 3. Construction du modèle ANN
model = Sequential([
    Dense(128, activation='relu', input_shape=(x_train.shape[1],)),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(32, activation='relu'),
    Dense(32, activation='relu'),
    Dense(6, activation='softmax')  # 3 classes
])

# 4. Compilation du modèle
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',  # Pour one-hot
    metrics=['accuracy']
)

# 5. EarlyStopping pour éviter overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# 6. Entraînement du modèle
model.fit(x_train_scaled, y_train_cat,
          epochs=80,
          batch_size=64,
          validation_data=(x_test_scaled, y_test_cat),
          callbacks=[early_stopping],
          verbose=1)

# 7. Évaluation du modèle
y_pred_proba = model.predict(x_test_scaled)
y_pred = tf.argmax(y_pred_proba, axis=1).numpy()  # classe prédite
y_true = tf.argmax(y_test_cat, axis=1).numpy()    # vraie classe

# 8. Métriques de classification multi-classe
accuracy = accuracy_score(y_true, y_pred)
recall = recall_score(y_true, y_pred, average='macro')
precision = precision_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

# 9. Affichage
print("\nRésultats :")
print(f"Accuracy  : {accuracy:.4f}")
print(f"Recall    : {recall:.4f}")
print(f"Precision : {precision:.4f}")
print(f"F1-score  : {f1:.4f}")
print("\nRapport détaillé :")
print(classification_report(y_true, y_pred, target_names=[ "Obesity_Type_III", "Insufficient_Weight", "Obesity_Type_I", "Overweight_Level_I", "Normal_Weight", 
    "Overweight_Level_II"]))
# Out:
# Epoch 1/80
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.2593 - loss: 1.7518 - val_accuracy: 0.4124 - val_loss: 1.6673
# Epoch 2/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4247 - loss: 1.5941 - val_accuracy: 0.4742 - val_loss: 1.4246
# Epoch 3/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4825 - loss: 1.3112 - val_accuracy: 0.5670 - val_loss: 1.1779
# Epoch 4/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5897 - loss: 1.0844 - val_accuracy: 0.6598 - val_loss: 0.9965
# Epoch 5/80
# ...

# %% [markdown]
# ### 5) Test réel du modèle choisi : ...

# %%
y_final_pred = model_gradientBoosting.predict(x_final_test)
print(f'Rélle : {y_final_test}')
print( f'Prédiction : {y_final_pred}')
# Out:
# Rélle : [3 3 0 4 0 2 4]
# Prédiction : [3 3 0 4 0 2 4]

# %%
# Assurez-vous que x_final_test a les bonnes colonnes (mêmes que top_features_list)
x_final_test = pd.DataFrame(x_final_test, columns=x_list)  # si nécessaire
x_final_test_top = x_final_test[top_features_list]

# Prédiction finale
y_final_pred = model_gradientBoosting_top.predict(x_final_test_top)


print(f'Rélle : {y_final_test}')
print( f'Prédiction : {y_final_pred}')
# Out:
# Rélle : [3 3 0 4 0 2 4]
# Prédiction : [3 3 0 4 0 2 4]

# %%
y_final_pred = model_xgboost.predict(x_final_test)
print(f'Rélle : {y_final_test}')
print( f'Prédiction : {y_final_pred}')
# Out:
# Rélle : [3 3 0 4 0 2 4]
# Prédiction : [3 3 0 4 0 2 4]

# %% [markdown]
# ### 6) Sauvegarde du modèle choisi : ...

# %%
import pickle

# %%
with open ('obesite_model_gradientBoosting.pkl', 'wb' ) as file :
     pickle.dump(model_gradientBoosting , file)

# %%
with open ('obesite_model_gradientBoosting_top.pkl', 'wb' ) as file :
     pickle.dump(model_gradientBoosting_top , file)

# %%
with open('encodeurs.pkl', 'wb') as file:
    pickle.dump(label_encoders , file)

# %%
# with open ('obesite_model_gradientBoosting.pkl', 'rb' ) as file : 
#     obesite_model_gradientBoosting = pickle.load(file)
